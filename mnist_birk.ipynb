# %% [markdown]
# # Neural Networks on MNIST
#
# This Jupyter notebook explains various approaches for implementing neural networks that recognize digits on [MNIST](http://yann.lecun.com/exdb/mnist/) dataset.

# %% [markdown]
# ## Preparing the MNIST dataset
#
# Most deep learning frameworks provide APIs for loading famous datasets like MNIST (e.g., `torchvision.datasets.MNIST` in pytorch). The APIs are handy, but hide the important step for preparing a training data for a deep learning framework; when graduating from an example dataset to the real data, we must convert a training data of our interest into the data structure that is acceptable by a deep learning framework.
#
# The cell below downloads the original distribution of the MNIST dataset on the Web, converts the dataset into `numpy` arrays, and saves the arrays as the file `mnist.npz` with keyword names.

# %%
import gzip
import os
import sys
import struct
import numpy as np

def read_image(fi):
    magic, n, rows, columns = struct.unpack(">IIII", fi.read(16))
    assert magic == 0x00000803
    assert rows == 28
    assert columns == 28
    rawbuffer = fi.read()
    assert len(rawbuffer) == n * rows * columns
    rawdata = np.frombuffer(rawbuffer, dtype='>u1', count=n*rows*columns)
    return rawdata.reshape(n, rows, columns).astype(np.float32) / 255.0

def read_label(fi):
    magic, n = struct.unpack(">II", fi.read(8))
    assert magic == 0x00000801
    rawbuffer = fi.read()
    assert len(rawbuffer) == n
    return np.frombuffer(rawbuffer, dtype='>u1', count=n)

if __name__ == '__main__':
    os.system('wget -N http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz')
    os.system('wget -N http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz')
    os.system('wget -N http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz')
    os.system('wget -N http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz')

    np.savez_compressed(
        'mnist',
        train_x=read_image(gzip.open('train-images-idx3-ubyte.gz', 'rb')),
        train_y=read_label(gzip.open('train-labels-idx1-ubyte.gz', 'rb')),
        test_x=read_image(gzip.open('t10k-images-idx3-ubyte.gz', 'rb')),
        test_y=read_label(gzip.open('t10k-labels-idx1-ubyte.gz', 'rb'))
    )

# %% [markdown]
# The file contains four numpy arrays (one tensor and array for each split of training and test sets) with the keywords:
#
# + `train_x`: $60000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `train_y`: $60000 \text{ (labels)}$
# + `test_x`: $10000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `test_y`: $10000 \text{ (labels)}$

# %%
import numpy as np
data = np.load('mnist.npz')

print(data['train_x'].shape, data['train_x'].dtype)
print(data['train_y'].shape, data['train_y'].dtype)
print(data['test_x'].shape, data['test_x'].dtype)
print(data['test_y'].shape, data['test_y'].dtype)
# Out:
# (60000, 28, 28) float32
# (60000,) uint8
# (10000, 28, 28) float32
# (10000,) uint8

# %% [markdown]
# ## Visualize the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Index number of an instance (change this to view another instance).
i = 0

data = np.load('mnist.npz')
image = data['train_x'][i]
label = data['train_y'][i]

print(label)
f, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(image, annot=True, fmt='.1f', square=True, cmap="YlGnBu")
plt.show()
# Out:
# 5

# %% [markdown]
# ## Install a library for plotting loss and accuracy values

# %%
# !pip install livelossplot
# Out:
# Collecting livelossplot
#   Downloading livelossplot-0.5.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.7.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.10/dist-packages (from livelossplot) (3.2.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (23.1)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh->livelossplot) (2023.7.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->livelossplot) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh->livelossplot) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh->livelossplot) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->livelossplot) (1.16.0)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.5.5

# %% [markdown]
# ## Perceptron algorithm for single-layer neural network

# %%
import numpy as np
from livelossplot import PlotLosses

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))     # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]    # Append 1: (N x 784) -> (N x 785)

data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])
Ytrain = data['train_y']
Xtest = image_to_vector(data['test_x'])
Ytest = data['test_y']

W = np.random.randn(10, 28*28+1)

eta = 0.001
liveloss = PlotLosses()
for t in range(100):
    # Structured perceptron for updating weights.
    num_correct_train = 0
    for x, y in zip(Xtrain, Ytrain):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred != y:
            W[y] += x * eta
            W[y_pred] -= x * eta
        else:
            num_correct_train += 1

    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1

    # Visualize accuracy values on the training and test sets.
    liveloss.update({
        'accuracy': float(num_correct_train) / len(Ytrain),
        'val_accuracy': float(num_correct_test) / len(Ytest)
    })
    liveloss.draw()

print('Accuracy: {:.4f} (test), {:.4f} (train)'.format(
    float(num_correct_test) / len(Ytest),
    float(num_correct_train) / len(Ytrain)
    ))
# Out:
# accuracy
# 	training         	 (min:    0.582, max:    0.889, cur:    0.889)
# 	validation       	 (min:    0.755, max:    0.886, cur:    0.886)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-585285162a08> in <cell line: 18>()
#      20     num_correct_train = 0
#      21     for x, y in zip(Xtrain, Ytrain):
# ---> 22         y_pred = np.argmax(np.dot(W, x))
#      23         if y_pred != y:
#      24             W[y] += x * eta
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in argmax(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in argmax(a, axis, out, keepdims)
#    1214     """
#    1215     kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216     return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#    1217
#    1218
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      49
#      50
# ---> 51 def _wrapfunc(obj, method, *args, **kwds):
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Stochastic gradient descent for single-layer neural network

# %%
import numpy as np
from livelossplot import PlotLosses

def softmax(x):
    # Result of softmax are invariant even if we add/subtract a constant.
    ex = np.exp(x - np.max(x))  # Subtract such that the maximum value is one.
    return ex / ex.sum(axis=0)

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))     # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]    # Append 1: (N x 784) -> (N x 785)

def label_to_onehot(Y, K):
    return np.eye(K)[Y]              # e.g., 3 -> [0, 0, 0, 1, 0, 0, 0, 0, 0]

data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])
Ytrain = label_to_onehot(data['train_y'], 10)
Xtest = image_to_vector(data['test_x'])
Ytest = data['test_y']

W = np.random.randn(10, 28*28+1)

eta = 0.001
liveloss = PlotLosses()
for t in range(100):
    num_correct_train = 0

    # Stochastic gradient descent.
    for x, y in zip(Xtrain, Ytrain):
        y_pred = softmax(np.dot(W, x))
        W += np.outer(eta * (y - y_pred), x)
        if  np.argmax(y_pred) == np.argmax(y):
            num_correct_train += 1

    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1

    # Visualize accuracy values on the training and test sets.
    liveloss.update({
        'accuracy': float(num_correct_train) / len(Ytrain),
        'val_accuracy': float(num_correct_test) / len(Ytest)
    })
    liveloss.draw()

print('Accuracy: {:.4f} (test), {:.4f} (train)'.format(
    float(num_correct_test) / len(Ytest),
    float(num_correct_train) / len(Ytrain)
    ))
# Out:
# Accuracy: 0.9182 (test), 0.9246 (train)

# %% [markdown]
# ## Training with pytorch

# %% [markdown]
# ### Install pytorch

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %% [markdown]
# ### Convert the numpy arrays into pytorch tensor

# %%
def create_dataset(x, y, flatten=False):
    if flatten:
        # Convert it into a matrix (N [samples], 28*28 [dims])
        xt = torch.from_numpy(x).view(len(x), -1)
    else:
        # Convert it into a 4D tensor (N [samples], 1 [ch], 28 [px], 28 [px])
        xt = torch.from_numpy(x).unsqueeze(1)
    yt = torch.from_numpy(y).long()
    return TensorDataset(xt, yt)

def test_model(model, loss_fn, test_loader, device):
    model.eval()

    loss = 0.
    num_correct = 0.
    for batch_idx, (x, y) in enumerate(test_loader):
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        loss += loss_fn(y_pred, y).item()
        _, predicted = torch.max(y_pred.data, 1)
        num_correct += (predicted == y).sum().item()

    model.train()
    loss /= len(test_loader.dataset)
    num_correct /= len(test_loader.dataset)
    return loss, num_correct

# %% [markdown]
# ### Single-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

def create_dataset(x, y):
    xt = torch.from_numpy(x).view(len(x), -1)
    yt = torch.from_numpy(y).long()
    return TensorDataset(xt, yt)

model = nn.Sequential()
model.add_module('fc1', nn.Linear(784, 10, bias=True))
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'])
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)

loss_fn = nn.CrossEntropyLoss(size_average=False)
optimizer = optim.SGD(model.parameters(), lr=0.001)

for t in range(100):
    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)

        # Compute the loss value.
        loss = loss_fn(y_pred, y)

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from livelossplot import PlotLosses

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1', nn.Linear(784, 10, bias=True))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss(size_average=False)
optimizer = optim.SGD(model.parameters(), lr=0.001)

liveloss = PlotLosses()
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Visualize the loss and accuracy values.
    liveloss.update({
        'log loss': train_loss,
        'val_log loss': test_loss,
        'accuracy': train_correct,
        'val_accuracy': test_correct,
    })
    liveloss.draw()

print('Accuracy: {:.4f} (test), {:.4f} (train)'.format(test_correct, train_correct))
# Out:
# Sequential(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
# )
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-87cdc8205e55> in <cell line: 17>()
#      15
#      16 data = np.load('mnist.npz')
# ---> 17 train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
#      18 test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
#      19 train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
#
# TypeError: create_dataset() got an unexpected keyword argument 'flatten'

# %% [markdown]
# ### Three-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from livelossplot import PlotLosses

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1',      nn.Linear(784, 256))
model.add_module('relu1',    nn.ReLU())
model.add_module('dropout1', nn.Dropout())
model.add_module('fc2',      nn.Linear(256, 256))
model.add_module('relu2',    nn.ReLU())
model.add_module('dropout2', nn.Dropout())
model.add_module('fc3',      nn.Linear(256, 10))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss(size_average=False)
optimizer = optim.SGD(model.parameters(), lr=0.001)

liveloss = PlotLosses()
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Visualize the loss and accuracy values.
    liveloss.update({
        'log loss': train_loss,
        'val_log loss': test_loss,
        'accuracy': train_correct,
        'val_accuracy': test_correct,
    })
    liveloss.draw()

print('Accuracy: {:.4f} (test), {:.4f} (train)'.format(test_correct, train_correct))
# Out:
# Accuracy: 0.9832 (test), 0.9908 (train)

# %% [markdown]
# ### Convolutional Neural Network (CNN)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from livelossplot import PlotLosses

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

class Flatten(torch.nn.Module):
    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        return x.view(-1, 512)

model = torch.nn.Sequential(
    torch.nn.Conv2d(1, 16, (5, 5)),
    torch.nn.MaxPool2d(2),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Conv2d(16, 32, (5, 5)),
    torch.nn.MaxPool2d(2),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    Flatten(),
    torch.nn.Linear(512, 256),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Linear(256, 10),
)
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'])
test_set = create_dataset(data['test_x'], data['test_y'])
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss(size_average=False)
optimizer = optim.SGD(model.parameters(), lr=0.001)

liveloss = PlotLosses()
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Visualize the loss and accuracy values.
    liveloss.update({
        'log loss': train_loss,
        'val_log loss': test_loss,
        'accuracy': train_correct,
        'val_accuracy': test_correct,
    })
    liveloss.draw()

print('Accuracy: {:.4f} (test), {:.4f} (train)'.format(test_correct, train_correct))
# Out:
# Accuracy: 0.9949 (test), 0.9856 (train)

# %%
import torch
import torch.nn as nn
data = "Transformers is a media franchise produced by American toy company Hasbro and Japanese toy company Takara Tomy   It primarily follows the heroic Autobots and the villainous Decepticons   two alien robot factions at war that can transform into other forms   such as vehicles and animals   The franchise encompasses toys   animation   comic books   video games and films   As of            it generated more than      trillion          billion   in revenue         making it one of the highest  grossing media franchises of all time  The franchise began in          with the Transformers toy line   comprising transforming mecha toys from Takara  s Diaclone and Micro Change toylines rebranded for Western markets         The term   Generation      covers both the animated television series The Transformers and the comic book series of the same name   which are further divided into Japanese   British and Canadian spin  offs   respectively   Sequels followed   such as the Generation    comic book and Beast Wars TV series   which became its own mini  universe   Generation    characters underwent two reboots with Dreamwave Productions in          and IDW Publishing in            with a third starting in            There have been other incarnations of the story based on different toy lines during and after the     th century   The first was the Robots in Disguise series   followed by three shows   Armada   Energon   and Cybertron   that constitute a single universe called the   Unicron Trilogy    A live  action film series started in            again distinct from previous incarnations   while the Transformers   Animated series merged concepts from the G   continuity   the          live  action film and the   Unicron Trilogy     For most of the         s   in an attempt to mitigate the wave of reboots   the   Aligned Continuity   was established   In            Transformers   Cyberverse debuted   once again   distinct from the previous incarnations  Although initially a separate and competing franchise started in            Tonka  s GoBots became the intellectual property of Hasbro after their buyout of Tonka in            Subsequently   the universe depicted in the animated series Challenge of the GoBots and follow  up film GoBots   Battle of the Rock Lords was retroactively established as an alternate universe within the Transformers multiverse        FictionTransformers   Generation                          Main articles   Transformers   Generation    and The Transformers   TV series  Classic Transformers franchise logo used until         Spider  Man battles Megatron on the cover of The Transformers       Generation One is a retroactive term for the Transformers characters that appeared between          and            The Transformers began with the         s Japanese toy lines Micro Change and Diaclone   They presented robots able to transform into everyday vehicles   electronic items or weapons   Hasbro bought the Micro Change and Diaclone toys   and partnered with Takara         Marvel Comics was hired by Hasbro to create the backstory   editor  in  chief Jim Shooter wrote an overall story   and gave the task of creating the characters to writer Dennis O  Neil         Unhappy with O  Neil  s work   although O  Neil created the name   Optimus Prime       Shooter chose Bob Budiansky to create the characters        The Transformers mecha were largely designed by Shōji Kawamori   the creator of the Japanese mecha anime franchise Macross   which was adapted into the Robotech franchise in North America           Kawamori came up with the idea of transforming mechs while working on the Diaclone and Macross franchises in the early         s   such as the VF     Valkyrie in Macross and Robotech     with his Diaclone mechs later providing the basis for Transformers        The primary concept of Generation One is that the heroic Optimus Prime   the villainous Megatron   and their finest soldiers crash land on pre  historic Earth in the Ark and the Nemesis before awakening in            Cybertron hurtling through the Neutral zone as an effect of the war   The Marvel comic was originally part of the main Marvel Universe   with appearances from Spider  Man and Nick Fury   plus some cameos         as well as a visit to the Savage Land          The Transformers TV series began around the same time   Produced by Sunbow Productions and Marvel Productions   later Hasbro Productions   from the start it contradicted Budiansky  s backstories   The TV series shows the Autobots looking for new energy sources   and crash landing as the Decepticons attack           Marvel interpreted the Autobots as destroying a rogue asteroid approaching Cybertron           Shockwave is loyal to Megatron in the TV series   keeping Cybertron in a stalemate during his absence           but in the comic book he attempts to take command of the Decepticons           The TV series would also differ wildly from the origins Budiansky had created for the Dinobots                   the Decepticon turned Autobot Jetfire           known as Skyfire on TV             the Constructicons   who combine to form Devastator                     and Omega Supreme                   The Marvel comic establishes early on that Prime wields the Creation Matrix   which gives life to machines   In the second season   the two  part episode The Key to Vector Sigma introduced the ancient Vector Sigma computer   which served the same original purpose as the Creation Matrix   giving life to Transformers     and its guardian Alpha Trion  In            the cartoon became the film The Transformers   The Movie   which is set in the year            It introduced the Matrix as the   Autobot Matrix of Leadership     as a fatally wounded Prime gives it to Ultra Magnus   however   as Prime dies he drops the matrix   which is then caught by Hot Rod who subsequently becomes Rodimus Prime later on in the film   Unicron   a transformer who devours planets   fears its power and recreates a heavily damaged Megatron as Galvatron   as well as Bombshell or Skywarp becoming Cyclonus   Thundercracker becoming Scourge and two other Insecticons becoming Scourge  s huntsmen   the Sweeps   Eventually   Rodimus Prime takes out the Matrix and destroys Unicron           In the United Kingdom   the weekly comic book interspliced original material to keep up with U  S   reprints           and The Movie provided much new material   Writer Simon Furman proceeded to expand the continuity with movie spin  offs involving the time travelling Galvatron                   The Movie also featured guest voices from Leonard Nimoy as Galvatron   Scatman Crothers as Jazz   Casey Kasem as Cliffjumper   Orson Welles as Unicron and Eric Idle as the leader of the Junkions   Wreck  Gar   though unnamed in the movie     The Transformers theme tune for the film was performed by Lion with   Weird Al   Yankovic adding a song to the soundtrack  The third season followed up The Movie   with the revelation of the Quintessons having used Cybertron as a factory   Their robots rebel   and in time the workers become the Autobots and the soldiers become the Decepticons     Note   This appears to contradict background presented in the first two seasons of the series     It is the Autobots who develop transformation           Due to popular demand           Optimus Prime is resurrected at the conclusion of the third season           and the series ended with a three  episode story arc   However   the Japanese broadcast of the series was supplemented with a newly produced OVA   Scramble City   before creating entirely new series to continue the storyline   ignoring the          end of the American series   The extended Japanese run consisted of The Headmasters   Super  God Masterforce   Victory and Zone   then in illustrated magazine form as Battlestars   Return of Convoy and Operation   Combination   Just as the TV series was wrapping up   Marvel continued to expand its continuity   It followed The Movie  s example by killing Prime         and Megatron           albeit in the present day   Dinobot leader Grimlock takes over as Autobot leader           There was a G  I   Joe crossover         and the limited series The Transformers   Headmasters   which further expanded the scope to the planet Nebulon           It led on to the main title resurrecting Prime as a Powermaster          "


#"The franchise began in 1984 with the Transformers toy line, comprising transforming mecha toys from Takara's Diaclone and Micro Change toylines rebranded for Western markets.[2] The term Generation 1 covers both the animated television series The Transformers and the comic book series of the same name, which are further divided into Japanese, British and Canadian spin-offs, respectively. Sequels followed, such as the Generation 2 comic book and Beast Wars TV series, which became its own mini-universe. Generation 1 characters underwent two reboots with Dreamwave Productions in 2001 and IDW Publishing in 2005, with a third starting in 2019. There have been other incarnations of the story based on different toy lines during and after the 20th century. The first was the Robots in Disguise series, followed by three shows (Armada, Energon, and Cybertron) that constitute a single universe called the Unicron Trilogy"

data = data.replace(".", "")
data.replace(",","")

data = data.lower()
data = data.split(" ")


uniques = len(set(data))
print(uniques)
words = list(set(data))

numdata = []
for word in data:
  numdata.append(words.index(word))

numdata = torch.IntTensor(numdata)
print(numdata)
# Out:
# 519
# tensor([381,  41, 322,  ...,   0,   0,   0], dtype=torch.int32)

# %%
import math



class self_attention(nn.Module):
  def __init__(self):
    super().__init__()

    self.Q = nn.Linear(12, 12)
    self.K = nn.Linear(12, 12)
    self.V = nn.Linear(12, 12)
    self.softmax = nn.Softmax(dim=0)
    self.embedding = nn.Embedding(519,12)
    self.flatten = nn.Flatten(start_dim=0)
    self.preoutput = nn.Linear(144,512)
    self.gelu = nn.GELU()
    self.output = nn.Linear(512, 519)

  def forward(self, x):
    x = self.embedding(x)
    x_q = self.Q(x)
    x_k = self.K(x)
    x_v = self.V(x)
    x_qk =  x_q.matmul(x_k.transpose(0,1))/math.sqrt(12)
    x = self.softmax(x_qk).matmul(x_v)
    x = self.flatten(x)
    x=self.preoutput(x)
    x = self.gelu(x)
    x = self.output(x)

    return x


self_atten = self_attention()

p = self_atten(numdata[:12])

optimizer = torch.optim.Adam(self_atten.parameters(), lr = 0.0001)
loss = nn.CrossEntropyLoss()

for i in range(100):
  for i in range(len(numdata)-13):
    optimizer.zero_grad()
    x = numdata[i:i+12]
    y = torch.zeros(519)
    y[numdata[i+13]] = 1
    y_p = self_atten(x)
    l = loss(y_p, y)
    print(l)
    l.backward()
    optimizer.step()


p = self_atten(numdata[:12])

print(p, words[p.argmax()], data[13])

for i in range(len(numdata)-13):
  x = numdata[i:i+12]
  y = data[i+13]
  y_p = self_atten(x)
  #print(y, words[y_p.argmax()])
  if y != words[y_p.argmax()]:
    print("Wrong!")
# Out:
# Streaming output truncated to the last 5000 lines.
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(1.7285e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.4212e-05, grad_fn=<DivBackward1>)
# tensor(8.9407e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.2769e-05, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(8.3681e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.8517e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.5020e-05, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0077, grad_fn=<DivBackward1>)
# tensor(0.0763, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0020, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(4.7921e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.8477e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.9020e-05, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.9087e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(9.0953e-05, grad_fn=<DivBackward1>)
# tensor(5.4836e-06, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0116, grad_fn=<DivBackward1>)
# tensor(0.0126, grad_fn=<DivBackward1>)
# tensor(0.0192, grad_fn=<DivBackward1>)
# tensor(0.0144, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0046, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.9709e-05, grad_fn=<DivBackward1>)
# tensor(7.3669e-05, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(1.0371e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(8.3801e-05, grad_fn=<DivBackward1>)
# tensor(3.2067e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(5.9604e-06, grad_fn=<DivBackward1>)
# tensor(0.0026, grad_fn=<DivBackward1>)
# tensor(0.0038, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.0914e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(4.0650e-05, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(6.2702e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(3.8861e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.4186e-05, grad_fn=<DivBackward1>)
# tensor(0.0050, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0519, grad_fn=<DivBackward1>)
# tensor(0.0083, grad_fn=<DivBackward1>)
# tensor(0.0034, grad_fn=<DivBackward1>)
# tensor(0.0049, grad_fn=<DivBackward1>)
# tensor(7.1761e-05, grad_fn=<DivBackward1>)
# tensor(3.2186e-06, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.5325e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(1.6689e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.0371e-05, grad_fn=<DivBackward1>)
# tensor(2.6106e-05, grad_fn=<DivBackward1>)
# tensor(4.2915e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.6226e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.4848e-05, grad_fn=<DivBackward1>)
# tensor(3.3974e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(2.0504e-05, grad_fn=<DivBackward1>)
# tensor(5.7219e-05, grad_fn=<DivBackward1>)
# tensor(5.1260e-06, grad_fn=<DivBackward1>)
# tensor(6.6755e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(8.1062e-06, grad_fn=<DivBackward1>)
# tensor(5.6028e-06, grad_fn=<DivBackward1>)
# tensor(5.5669e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.1563e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(5.3285e-05, grad_fn=<DivBackward1>)
# tensor(5.7219e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(7.8913e-05, grad_fn=<DivBackward1>)
# tensor(1.2994e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(8.2966e-05, grad_fn=<DivBackward1>)
# tensor(1.0729e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(4.1723e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(8.1059e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(3.8147e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.6570e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(7.4265e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.4318e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(5.0068e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0188, grad_fn=<DivBackward1>)
# tensor(2.9900, grad_fn=<DivBackward1>)
# tensor(0.0076, grad_fn=<DivBackward1>)
# tensor(0.0105, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(8.8569e-05, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.2636e-05, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(2.0861e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0045, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0138, grad_fn=<DivBackward1>)
# tensor(0.0127, grad_fn=<DivBackward1>)
# tensor(0.0274, grad_fn=<DivBackward1>)
# tensor(0.0075, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(2.0027e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(0.0065, grad_fn=<DivBackward1>)
# tensor(0.3023, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(7.0333e-06, grad_fn=<DivBackward1>)
# tensor(1.9431e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(2.1934e-05, grad_fn=<DivBackward1>)
# tensor(1.4901e-05, grad_fn=<DivBackward1>)
# tensor(1.9789e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(6.2464e-05, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0016, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0016, grad_fn=<DivBackward1>)
# tensor(0.0025, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(3.6477e-05, grad_fn=<DivBackward1>)
# tensor(1.0014e-05, grad_fn=<DivBackward1>)
# tensor(8.1062e-06, grad_fn=<DivBackward1>)
# tensor(9.3098e-05, grad_fn=<DivBackward1>)
# tensor(2.7418e-06, grad_fn=<DivBackward1>)
# tensor(5.5550e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.6332e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(6.9141e-06, grad_fn=<DivBackward1>)
# tensor(1.1206e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(3.9696e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(6.4371e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.0967e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0091, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0049, grad_fn=<DivBackward1>)
# tensor(0.0135, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(0.0029, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0024, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(8.7022e-06, grad_fn=<DivBackward1>)
# tensor(0.0016, grad_fn=<DivBackward1>)
# tensor(0.0020, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.5391e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1682e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.2875e-05, grad_fn=<DivBackward1>)
# tensor(1.9550e-05, grad_fn=<DivBackward1>)
# tensor(9.5367e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.0610e-05, grad_fn=<DivBackward1>)
# tensor(2.0861e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(5.9604e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(4.0173e-05, grad_fn=<DivBackward1>)
# tensor(1.7643e-05, grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(4.1484e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(5.0663e-05, grad_fn=<DivBackward1>)
# tensor(5.7220e-06, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(6.8781e-05, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(1.6928e-05, grad_fn=<DivBackward1>)
# tensor(1.9312e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.2888e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.2888e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.4716e-05, grad_fn=<DivBackward1>)
# tensor(2.6822e-05, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(2.1815e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.4120e-05, grad_fn=<DivBackward1>)
# tensor(9.8943e-06, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(8.2254e-06, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(8.9407e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(2.9087e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.5656e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(3.9815e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0070, grad_fn=<DivBackward1>)
# tensor(0.0057, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0045, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(5.9604e-06, grad_fn=<DivBackward1>)
# tensor(3.9339e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.8781e-05, grad_fn=<DivBackward1>)
# tensor(2.5153e-05, grad_fn=<DivBackward1>)
# tensor(3.0636e-05, grad_fn=<DivBackward1>)
# tensor(8.1655e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0071, grad_fn=<DivBackward1>)
# tensor(2.9423, grad_fn=<DivBackward1>)
# tensor(0.0705, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(0.0045, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(9.1791e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.8014e-05, grad_fn=<DivBackward1>)
# tensor(3.6597e-05, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(4.3153e-05, grad_fn=<DivBackward1>)
# tensor(0.0051, grad_fn=<DivBackward1>)
# tensor(0.0029, grad_fn=<DivBackward1>)
# tensor(0.0097, grad_fn=<DivBackward1>)
# tensor(2.4309, grad_fn=<DivBackward1>)
# tensor(0.1476, grad_fn=<DivBackward1>)
# tensor(0.0199, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0047, grad_fn=<DivBackward1>)
# tensor(0.0108, grad_fn=<DivBackward1>)
# tensor(6.8662e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(0.0032, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(4.1723e-06, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(2.0265e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(4.0769e-05, grad_fn=<DivBackward1>)
# tensor(2.6941e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(3.2186e-06, grad_fn=<DivBackward1>)
# tensor(6.9377e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.8305e-05, grad_fn=<DivBackward1>)
# tensor(4.3987e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(9.2860e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.9073e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(6.6397e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(3.0994e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(0.0026, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(3.9815e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(7.6053e-05, grad_fn=<DivBackward1>)
# tensor(4.7206e-05, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.1100e-05, grad_fn=<DivBackward1>)
# tensor(9.8943e-06, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.2530e-05, grad_fn=<DivBackward1>)
# tensor(3.0636e-05, grad_fn=<DivBackward1>)
# tensor(8.3324e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(8.2254e-06, grad_fn=<DivBackward1>)
# tensor(6.9735e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.3365e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(2.3007e-05, grad_fn=<DivBackward1>)
# tensor(1.0848e-05, grad_fn=<DivBackward1>)
# tensor(1.9908e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(4.8517e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.0903, grad_fn=<DivBackward1>)
# tensor(2.5361, grad_fn=<DivBackward1>)
# tensor(0.0922, grad_fn=<DivBackward1>)
# tensor(0.0108, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(6.9735e-05, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.1989e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(6.4133e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(3.9457e-05, grad_fn=<DivBackward1>)
# tensor(9.2983e-06, grad_fn=<DivBackward1>)
# tensor(3.8981e-05, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(2.3365e-05, grad_fn=<DivBackward1>)
# tensor(8.7734e-05, grad_fn=<DivBackward1>)
# tensor(7.3909e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(3.6955e-06, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(1.5139e-05, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0105, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(4.4941e-05, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(2.9444e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(3.9219e-05, grad_fn=<DivBackward1>)
# tensor(4.5895e-05, grad_fn=<DivBackward1>)
# tensor(7.4861e-05, grad_fn=<DivBackward1>)
# tensor(2.0504e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(4.5060e-05, grad_fn=<DivBackward1>)
# tensor(2.5034e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(6.1510e-05, grad_fn=<DivBackward1>)
# tensor(0.0032, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(0.0069, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0101, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(4.2915e-06, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(2.2769e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.6464e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(2.5868e-05, grad_fn=<DivBackward1>)
# tensor(1.7285e-05, grad_fn=<DivBackward1>)
# tensor(2.5034e-06, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(1.7881e-06, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0047, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.7047e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(3.9934e-05, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0032, grad_fn=<DivBackward1>)
# tensor(0.4845, grad_fn=<DivBackward1>)
# tensor(1.2196, grad_fn=<DivBackward1>)
# tensor(2.4182, grad_fn=<DivBackward1>)
# tensor(0.1007, grad_fn=<DivBackward1>)
# tensor(0.0112, grad_fn=<DivBackward1>)
# tensor(0.0254, grad_fn=<DivBackward1>)
# tensor(0.0179, grad_fn=<DivBackward1>)
# tensor(0.0118, grad_fn=<DivBackward1>)
# tensor(5.9604e-06, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0095, grad_fn=<DivBackward1>)
# tensor(0.0016, grad_fn=<DivBackward1>)
# tensor(0.0041, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0038, grad_fn=<DivBackward1>)
# tensor(1.0729e-05, grad_fn=<DivBackward1>)
# tensor(2.6226e-06, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(4.3749e-05, grad_fn=<DivBackward1>)
# tensor(2.7418e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(8.2370e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.8398e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(3.4571e-06, grad_fn=<DivBackward1>)
# tensor(4.6014e-05, grad_fn=<DivBackward1>)
# tensor(1.5259e-05, grad_fn=<DivBackward1>)
# tensor(3.9481, grad_fn=<DivBackward1>)
# tensor(0.7840, grad_fn=<DivBackward1>)
# tensor(0.1127, grad_fn=<DivBackward1>)
# tensor(0.0251, grad_fn=<DivBackward1>)
# tensor(0.0594, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(6.2941e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(6.3181e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.9087e-05, grad_fn=<DivBackward1>)
# tensor(3.8504e-05, grad_fn=<DivBackward1>)
# tensor(1.1325e-05, grad_fn=<DivBackward1>)
# tensor(2.9802e-06, grad_fn=<DivBackward1>)
# tensor(1.9193e-05, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(7.1525e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0053, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.3164, grad_fn=<DivBackward1>)
# tensor(0.1841, grad_fn=<DivBackward1>)
# tensor(0.3168, grad_fn=<DivBackward1>)
# tensor(0.0426, grad_fn=<DivBackward1>)
# tensor(0.0166, grad_fn=<DivBackward1>)
# tensor(0.0062, grad_fn=<DivBackward1>)
# tensor(0.0041, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.1961e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(3.1590e-05, grad_fn=<DivBackward1>)
# tensor(9.4175e-06, grad_fn=<DivBackward1>)
# tensor(2.8848e-05, grad_fn=<DivBackward1>)
# tensor(5.3643e-05, grad_fn=<DivBackward1>)
# tensor(8.9761e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(5.9126e-05, grad_fn=<DivBackward1>)
# tensor(3.1948e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(3.9339e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.7060e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(9.7751e-06, grad_fn=<DivBackward1>)
# tensor(4.4107e-06, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(0.0018, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0072, grad_fn=<DivBackward1>)
# tensor(0.0081, grad_fn=<DivBackward1>)
# tensor(0.0042, grad_fn=<DivBackward1>)
# tensor(0.0113, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0052, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0068, grad_fn=<DivBackward1>)
# tensor(0.0494, grad_fn=<DivBackward1>)
# tensor(0.1055, grad_fn=<DivBackward1>)
# tensor(0.1035, grad_fn=<DivBackward1>)
# tensor(0.1003, grad_fn=<DivBackward1>)
# tensor(0.0961, grad_fn=<DivBackward1>)
# tensor(0.0913, grad_fn=<DivBackward1>)
# tensor(0.0860, grad_fn=<DivBackward1>)
# tensor(0.0806, grad_fn=<DivBackward1>)
# tensor(0.0750, grad_fn=<DivBackward1>)
# tensor(0.0697, grad_fn=<DivBackward1>)
# tensor(0.0645, grad_fn=<DivBackward1>)
# tensor(0.0596, grad_fn=<DivBackward1>)
# tensor(0.0550, grad_fn=<DivBackward1>)
# tensor(5.7804, grad_fn=<DivBackward1>)
# tensor(5.5037, grad_fn=<DivBackward1>)
# tensor(0.2239, grad_fn=<DivBackward1>)
# tensor(0.2124, grad_fn=<DivBackward1>)
# tensor(0.0439, grad_fn=<DivBackward1>)
# tensor(0.0231, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(0.0163, grad_fn=<DivBackward1>)
# tensor(9.5482e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0069, grad_fn=<DivBackward1>)
# tensor(0.0103, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(1.6093e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.0623e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.7751e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.0133e-05, grad_fn=<DivBackward1>)
# tensor(9.1072e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0038, grad_fn=<DivBackward1>)
# tensor(0.0098, grad_fn=<DivBackward1>)
# tensor(2.5868e-05, grad_fn=<DivBackward1>)
# tensor(0.0019, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(8.1178e-05, grad_fn=<DivBackward1>)
# tensor(6.9141e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(5.2928e-05, grad_fn=<DivBackward1>)
# tensor(6.1391e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(4.5299e-06, grad_fn=<DivBackward1>)
# tensor(2.4080e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(6.2821e-05, grad_fn=<DivBackward1>)
# tensor(2.7656e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(8.5830e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.8252e-05, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(2.1934e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0214, grad_fn=<DivBackward1>)
# tensor(0.0056, grad_fn=<DivBackward1>)
# tensor(0.0035, grad_fn=<DivBackward1>)
# tensor(1.7047e-05, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0051, grad_fn=<DivBackward1>)
# tensor(0.0058, grad_fn=<DivBackward1>)
# tensor(0.0128, grad_fn=<DivBackward1>)
# tensor(0.0151, grad_fn=<DivBackward1>)
# tensor(0.0493, grad_fn=<DivBackward1>)
# tensor(2.5973, grad_fn=<DivBackward1>)
# tensor(0.0253, grad_fn=<DivBackward1>)
# tensor(0.0038, grad_fn=<DivBackward1>)
# tensor(0.0091, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0024, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(8.4873e-05, grad_fn=<DivBackward1>)
# tensor(8.5708e-05, grad_fn=<DivBackward1>)
# tensor(5.7934e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0028, grad_fn=<DivBackward1>)
# tensor(7.2119e-05, grad_fn=<DivBackward1>)
# tensor(1.2875e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(4.5299e-06, grad_fn=<DivBackward1>)
# tensor(6.5086e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(7.1525e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(6.3181e-06, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(3.4571e-06, grad_fn=<DivBackward1>)
# tensor(3.3379e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(3.6716e-05, grad_fn=<DivBackward1>)
# tensor(8.9407e-06, grad_fn=<DivBackward1>)
# tensor(5.2452e-06, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(6.5682e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(6.1989e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.2915e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.2159e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(6.9258e-05, grad_fn=<DivBackward1>)
# tensor(0.0020, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0021, grad_fn=<DivBackward1>)
# tensor(4.4226e-05, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(3.5763e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.9312e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(2.3842e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(2.8729e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(3.3379e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(7.8678e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(4.5299e-06, grad_fn=<DivBackward1>)
# tensor(3.5763e-06, grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(5.0068e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(9.4175e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.3378e-05, grad_fn=<DivBackward1>)
# tensor(2.6464e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(5.1974e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.0133e-05, grad_fn=<DivBackward1>)
# tensor(1.2755e-05, grad_fn=<DivBackward1>)
# tensor(0.0090, grad_fn=<DivBackward1>)
# tensor(6.5325e-05, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1325e-05, grad_fn=<DivBackward1>)
# tensor(3.9219e-05, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(3.3378e-05, grad_fn=<DivBackward1>)
# tensor(2.6226e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(3.6955e-06, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(5.0068e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.9604e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(3.9219e-05, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(2.3246e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(7.3909e-06, grad_fn=<DivBackward1>)
# tensor(8.5830e-06, grad_fn=<DivBackward1>)
# tensor(7.5218e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.8000e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(1.6451e-05, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(4.1723e-06, grad_fn=<DivBackward1>)
# tensor(5.7100e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(5.5669e-05, grad_fn=<DivBackward1>)
# tensor(1.3471e-05, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(5.2689e-05, grad_fn=<DivBackward1>)
# tensor(2.0981e-05, grad_fn=<DivBackward1>)
# tensor(3.8027e-05, grad_fn=<DivBackward1>)
# tensor(5.6861e-05, grad_fn=<DivBackward1>)
# tensor(2.9683e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.6955e-06, grad_fn=<DivBackward1>)
# tensor(1.0490e-05, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.5378e-05, grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(7.1525e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.9206e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0018, grad_fn=<DivBackward1>)
# tensor(0.0064, grad_fn=<DivBackward1>)
# tensor(0.0146, grad_fn=<DivBackward1>)
# tensor(0.0293, grad_fn=<DivBackward1>)
# tensor(0.0079, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0018, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.7949e-06, grad_fn=<DivBackward1>)
# tensor(1.8477e-05, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.6689e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.5616e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.1696e-05, grad_fn=<DivBackward1>)
# tensor(4.4702e-05, grad_fn=<DivBackward1>)
# tensor(5.0068e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.0266e-06, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.6451e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0149, grad_fn=<DivBackward1>)
# tensor(0.0191, grad_fn=<DivBackward1>)
# tensor(7.8678e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(3.6597e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(2.9683e-05, grad_fn=<DivBackward1>)
# tensor(1.7166e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(7.9271e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.8742e-05, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(3.8147e-06, grad_fn=<DivBackward1>)
# tensor(5.7815e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.9802e-06, grad_fn=<DivBackward1>)
# tensor(1.4186e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(4.0411e-05, grad_fn=<DivBackward1>)
# tensor(2.5034e-06, grad_fn=<DivBackward1>)
# tensor(2.3603e-05, grad_fn=<DivBackward1>)
# tensor(0.0026, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(6.9139e-05, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(6.7589e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(8.5469e-05, grad_fn=<DivBackward1>)
# tensor(7.5099e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.5895e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(1.9312e-05, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.8239e-05, grad_fn=<DivBackward1>)
# tensor(1.2994e-05, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.7299e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.7299e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(6.6636e-05, grad_fn=<DivBackward1>)
# tensor(6.0437e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.3974e-05, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(5.3285e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.7684e-07, grad_fn=<DivBackward1>)
# tensor(1.0967e-05, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0099, grad_fn=<DivBackward1>)
# tensor(4.0941, grad_fn=<DivBackward1>)
# tensor(0.0113, grad_fn=<DivBackward1>)
# tensor(0.0660, grad_fn=<DivBackward1>)
# tensor(8.4397e-05, grad_fn=<DivBackward1>)
# tensor(5.1259e-05, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.0371e-05, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(9.6912e-05, grad_fn=<DivBackward1>)
# tensor(1.3351e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.6941e-05, grad_fn=<DivBackward1>)
# tensor(2.9087e-05, grad_fn=<DivBackward1>)
# tensor(1.0133e-05, grad_fn=<DivBackward1>)
# tensor(6.5565e-06, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(4.5895e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# ...
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(0.0057, grad_fn=<DivBackward1>)
# tensor(2.8568, grad_fn=<DivBackward1>)
# tensor(0.0311, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0024, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(1.1206e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.8000e-05, grad_fn=<DivBackward1>)
# tensor(2.2888e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(4.7683e-05, grad_fn=<DivBackward1>)
# tensor(0.0039, grad_fn=<DivBackward1>)
# tensor(0.0024, grad_fn=<DivBackward1>)
# tensor(0.0076, grad_fn=<DivBackward1>)
# tensor(2.4092, grad_fn=<DivBackward1>)
# tensor(0.1239, grad_fn=<DivBackward1>)
# tensor(0.0165, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0087, grad_fn=<DivBackward1>)
# tensor(4.9590e-05, grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(0.0026, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(9.8581e-05, grad_fn=<DivBackward1>)
# tensor(2.8610e-06, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.8835e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(3.3140e-05, grad_fn=<DivBackward1>)
# tensor(1.8835e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.6689e-06, grad_fn=<DivBackward1>)
# tensor(2.1458e-06, grad_fn=<DivBackward1>)
# tensor(6.3417e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.9709e-05, grad_fn=<DivBackward1>)
# tensor(3.4332e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(7.4026e-05, grad_fn=<DivBackward1>)
# tensor(8.6423e-05, grad_fn=<DivBackward1>)
# tensor(1.6212e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(9.3217e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(5.6980e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(3.0279e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(9.3933e-05, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(0.0017, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.7895e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(8.2132e-05, grad_fn=<DivBackward1>)
# tensor(3.4809e-05, grad_fn=<DivBackward1>)
# tensor(1.3113e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.3590e-05, grad_fn=<DivBackward1>)
# tensor(1.1325e-05, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(9.3813e-05, grad_fn=<DivBackward1>)
# tensor(1.4663e-05, grad_fn=<DivBackward1>)
# tensor(2.9921e-05, grad_fn=<DivBackward1>)
# tensor(6.4371e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(5.6028e-06, grad_fn=<DivBackward1>)
# tensor(4.0650e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.5153e-05, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(1.8358e-05, grad_fn=<DivBackward1>)
# tensor(6.4373e-06, grad_fn=<DivBackward1>)
# tensor(1.6689e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.5153e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.0806, grad_fn=<DivBackward1>)
# tensor(2.4933, grad_fn=<DivBackward1>)
# tensor(0.0764, grad_fn=<DivBackward1>)
# tensor(0.0087, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(4.7683e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(4.2915e-06, grad_fn=<DivBackward1>)
# tensor(7.9509e-05, grad_fn=<DivBackward1>)
# tensor(8.6423e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(5.4716e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(2.6106e-05, grad_fn=<DivBackward1>)
# tensor(4.7684e-06, grad_fn=<DivBackward1>)
# tensor(2.8371e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(1.5616e-05, grad_fn=<DivBackward1>)
# tensor(7.5337e-05, grad_fn=<DivBackward1>)
# tensor(5.1260e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(3.5763e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.4543e-05, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0081, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0049, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(2.8371e-05, grad_fn=<DivBackward1>)
# tensor(3.5763e-07, grad_fn=<DivBackward1>)
# tensor(3.0398e-05, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(6.9139e-05, grad_fn=<DivBackward1>)
# tensor(3.2782e-05, grad_fn=<DivBackward1>)
# tensor(4.6729e-05, grad_fn=<DivBackward1>)
# tensor(7.4861e-05, grad_fn=<DivBackward1>)
# tensor(1.3232e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(3.2544e-05, grad_fn=<DivBackward1>)
# tensor(1.6689e-06, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(4.7802e-05, grad_fn=<DivBackward1>)
# tensor(0.0031, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0054, grad_fn=<DivBackward1>)
# tensor(0.0013, grad_fn=<DivBackward1>)
# tensor(0.0077, grad_fn=<DivBackward1>)
# tensor(0.0010, grad_fn=<DivBackward1>)
# tensor(2.7418e-06, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(1.5497e-06, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(1.3709e-05, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.1457e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(1.5974e-05, grad_fn=<DivBackward1>)
# tensor(1.2875e-05, grad_fn=<DivBackward1>)
# tensor(1.7881e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(1.6689e-06, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0036, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.3947e-05, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(5.4477e-05, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0020, grad_fn=<DivBackward1>)
# tensor(0.4432, grad_fn=<DivBackward1>)
# tensor(1.1745, grad_fn=<DivBackward1>)
# tensor(2.4154, grad_fn=<DivBackward1>)
# tensor(0.0786, grad_fn=<DivBackward1>)
# tensor(0.0075, grad_fn=<DivBackward1>)
# tensor(0.0205, grad_fn=<DivBackward1>)
# tensor(0.0135, grad_fn=<DivBackward1>)
# tensor(0.0090, grad_fn=<DivBackward1>)
# tensor(5.2452e-06, grad_fn=<DivBackward1>)
# tensor(0.0022, grad_fn=<DivBackward1>)
# tensor(0.0022, grad_fn=<DivBackward1>)
# tensor(0.0016, grad_fn=<DivBackward1>)
# tensor(0.0082, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(0.0033, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0028, grad_fn=<DivBackward1>)
# tensor(6.7949e-06, grad_fn=<DivBackward1>)
# tensor(1.7881e-06, grad_fn=<DivBackward1>)
# tensor(0.0020, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(7.1526e-07, grad_fn=<DivBackward1>)
# tensor(3.6001e-05, grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.0729e-06, grad_fn=<DivBackward1>)
# tensor(6.2941e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(3.3855e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(4.5299e-06, grad_fn=<DivBackward1>)
# tensor(4.0769e-05, grad_fn=<DivBackward1>)
# tensor(1.7762e-05, grad_fn=<DivBackward1>)
# tensor(3.7281, grad_fn=<DivBackward1>)
# tensor(0.8412, grad_fn=<DivBackward1>)
# tensor(0.0917, grad_fn=<DivBackward1>)
# tensor(0.0236, grad_fn=<DivBackward1>)
# tensor(0.0565, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(4.8875e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(4.4107e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(2.8133e-05, grad_fn=<DivBackward1>)
# tensor(3.9934e-05, grad_fn=<DivBackward1>)
# tensor(8.4638e-06, grad_fn=<DivBackward1>)
# tensor(2.2650e-06, grad_fn=<DivBackward1>)
# tensor(1.6451e-05, grad_fn=<DivBackward1>)
# tensor(1.4305e-06, grad_fn=<DivBackward1>)
# tensor(4.6133e-05, grad_fn=<DivBackward1>)
# tensor(1.2636e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(0.0037, grad_fn=<DivBackward1>)
# tensor(0.0052, grad_fn=<DivBackward1>)
# tensor(0.3403, grad_fn=<DivBackward1>)
# tensor(0.1941, grad_fn=<DivBackward1>)
# tensor(0.2417, grad_fn=<DivBackward1>)
# tensor(0.0351, grad_fn=<DivBackward1>)
# tensor(0.0141, grad_fn=<DivBackward1>)
# tensor(0.0048, grad_fn=<DivBackward1>)
# tensor(0.0037, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(5.9605e-07, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(2.8848e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(3.5405e-05, grad_fn=<DivBackward1>)
# tensor(9.5367e-06, grad_fn=<DivBackward1>)
# tensor(2.4795e-05, grad_fn=<DivBackward1>)
# tensor(4.7683e-05, grad_fn=<DivBackward1>)
# tensor(2.6226e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(8.9641e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(9.5367e-07, grad_fn=<DivBackward1>)
# tensor(4.6848e-05, grad_fn=<DivBackward1>)
# tensor(1.9908e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(8.8688e-05, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(4.5299e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(2.5749e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(5.7220e-06, grad_fn=<DivBackward1>)
# tensor(2.5034e-06, grad_fn=<DivBackward1>)
# tensor(1.1921e-06, grad_fn=<DivBackward1>)
# tensor(0.0015, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0034, grad_fn=<DivBackward1>)
# tensor(0.0040, grad_fn=<DivBackward1>)
# tensor(0.0061, grad_fn=<DivBackward1>)
# tensor(0.0034, grad_fn=<DivBackward1>)
# tensor(0.0072, grad_fn=<DivBackward1>)
# tensor(0.0009, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0044, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0095, grad_fn=<DivBackward1>)
# tensor(0.0339, grad_fn=<DivBackward1>)
# tensor(0.1067, grad_fn=<DivBackward1>)
# tensor(0.1049, grad_fn=<DivBackward1>)
# tensor(0.1018, grad_fn=<DivBackward1>)
# tensor(0.0978, grad_fn=<DivBackward1>)
# tensor(0.0931, grad_fn=<DivBackward1>)
# tensor(0.0879, grad_fn=<DivBackward1>)
# tensor(0.0825, grad_fn=<DivBackward1>)
# tensor(0.0771, grad_fn=<DivBackward1>)
# tensor(0.0717, grad_fn=<DivBackward1>)
# tensor(0.0665, grad_fn=<DivBackward1>)
# tensor(0.0615, grad_fn=<DivBackward1>)
# tensor(0.0569, grad_fn=<DivBackward1>)
# tensor(5.6830, grad_fn=<DivBackward1>)
# tensor(5.4255, grad_fn=<DivBackward1>)
# tensor(0.1922, grad_fn=<DivBackward1>)
# tensor(0.1470, grad_fn=<DivBackward1>)
# tensor(0.0370, grad_fn=<DivBackward1>)
# tensor(0.0238, grad_fn=<DivBackward1>)
# tensor(0.0027, grad_fn=<DivBackward1>)
# tensor(0.0023, grad_fn=<DivBackward1>)
# tensor(0.0150, grad_fn=<DivBackward1>)
# tensor(7.7841e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(0.0057, grad_fn=<DivBackward1>)
# tensor(0.0078, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.6928e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(8.2847e-05, grad_fn=<DivBackward1>)
# tensor(0.0005, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(-0., grad_fn=<DivBackward1>)
# tensor(2.3246e-05, grad_fn=<DivBackward1>)
# tensor(7.8794e-05, grad_fn=<DivBackward1>)
# tensor(1.1921e-07, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0006, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.8943e-06, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(9.1791e-06, grad_fn=<DivBackward1>)
# tensor(6.4371e-05, grad_fn=<DivBackward1>)
# tensor(0.0001, grad_fn=<DivBackward1>)
# tensor(0.0008, grad_fn=<DivBackward1>)
# tensor(0.0030, grad_fn=<DivBackward1>)
# tensor(0.0083, grad_fn=<DivBackward1>)
# tensor(1.5855e-05, grad_fn=<DivBackward1>)
# tensor(0.0014, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
# tensor(8.3446e-07, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(6.8305e-05, grad_fn=<DivBackward1>)
# tensor(6.0797e-06, grad_fn=<DivBackward1>)
# tensor(0.0003, grad_fn=<DivBackward1>)
# tensor(0.0004, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0007, grad_fn=<DivBackward1>)
# tensor(0.0012, grad_fn=<DivBackward1>)
# tensor(2.3842e-07, grad_fn=<DivBackward1>)
# tensor(3.2186e-05, grad_fn=<DivBackward1>)
# tensor(3.7193e-05, grad_fn=<DivBackward1>)
# tensor(0.0002, grad_fn=<DivBackward1>)
# tensor(0.0011, grad_fn=<DivBackward1>)
